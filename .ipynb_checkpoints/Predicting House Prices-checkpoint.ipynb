# %% [markdown]
# # Fire Up GraphLab Create

# %%
import graphlab

# %% [markdown]
# # Load Some House Sales Data

# %%
sales = graphlab.SFrame('home_data.sframe')
# Out:
# This non-commercial license of GraphLab Create for academic use is assigned to samridhiprasad19@gmail.com and will expire on May 10, 2021.
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: C:\Users\SAMRID~1\AppData\Local\Temp\graphlab_server_1590202723.log.0

# %%
sales
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 21613
#
# Data:
# +------------+---------------------------+-----------+----------+-----------+
# |     id     |            date           |   price   | bedrooms | bathrooms |
# +------------+---------------------------+-----------+----------+-----------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900.0 |   3.0    |    1.0    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000.0 |   3.0    |    2.25   |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000.0 |   2.0    |    1.0    |
# | 2487200875 | 2014-12-09 00:00:00+00:00 |  604000.0 |   4.0    |    3.0    |
# ...

# %% [markdown]
# # Exploring the data for housing sales

# %%
graphlab.canvas.set_target('ipynb')
sales.show(view = "Scatter Plot",x = 'sqft_living',y = 'price' )

# %% [markdown]
# # Create simple regression Model to sqft living to price

# %%
train_data,test_data = sales.random_split(.8,seed = 0) #here we are using seed because random split will split data in any 
#random numbers assigning numbers to seed ensures that we use same spliting of data.

# %% [markdown]
# ## Build a Regression Model

# %%
sqft_model = graphlab.linear_regression.create(train_data,target='price',features=['sqft_living'])
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 16571
# Number of features          : 1
# Number of unpacked features : 1
# Number of coefficients    : 2
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# | Iteration | Passes   | Elapsed Time | Training-max_error | Validation-max_error | Training-rmse | Validation-rmse |
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# | 1         | 2        | 1.006888     | 4352690.836336     | 2724572.490007       | 262323.721980 | 275278.179761   |
# ...

# %% [markdown]
# # Evaluate the test data

# %%
print test_data['price'].mean()
# Out:
# <pre></pre>
# 543054.042563

# %%
print sqft_model.evaluate(test_data)
# Out:
# {'max_error': 4146058.1623020708, 'rmse': 255186.04236762787}

# %% [markdown]
# # Visualizing Predictions

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(test_data['sqft_living'],test_data['price'],'.',
         test_data['sqft_living'],sqft_model.predict(test_data),'-')

# %%
sqft_model.coefficients
# Out:
# Columns:
# 	name	str
# 	index	str
# 	value	float
# 	stderr	float
#
# Rows: 2
#
# Data:
# +-------------+-------+----------------+---------------+
# |     name    | index |     value      |     stderr    |
# +-------------+-------+----------------+---------------+
# | (intercept) |  None | -46591.8909154 | 5040.23088096 |
# | sqft_living |  None | 281.651539799  | 2.21791029637 |
# +-------------+-------+----------------+---------------+
# [2 rows x 4 columns]

# %% [markdown]
# # Exploring Other Features

# %%
my_features = ['bedrooms','bathrooms','sqft_living','sqft_lot','floors','zipcode']

# %%
sales[my_features].show()

# %%
sales.show(view = 'BoxWhisker Plot', x ='zipcode',y= 'price')

# %% [markdown]
# # Building regression model with multiple features

# %%
my_feature_model= graphlab.linear_regression.create(train_data,target='price',features= my_features)
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 16483
# Number of features          : 6
# Number of unpacked features : 6
# Number of coefficients    : 75
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# | Iteration | Passes   | Elapsed Time | Training-max_error | Validation-max_error | Training-rmse | Validation-rmse |
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# | 1         | 2        | 0.296515     | 4064721.451301     | 1964329.137232       | 189954.645241 | 175744.151076   |
# ...

# %%
print sqft_model.evaluate(test_data)
print my_feature_model.evaluate(test_data)
# Out:
# {'max_error': 4146058.1623020708, 'rmse': 255186.04236762787}
# {'max_error': 3132604.113500305, 'rmse': 180635.2699496418}

# %% [markdown]
# # Apply Learned model to predict prices

# %%
house1 = sales[sales['id']=='5309101200']

# %%
house1
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: Unknown
#
# Data:
# +------------+---------------------------+----------+----------+-----------+
# |     id     |            date           |  price   | bedrooms | bathrooms |
# +------------+---------------------------+----------+----------+-----------+
# | 5309101200 | 2014-06-05 00:00:00+00:00 | 620000.0 |   4.0    |    2.25   |
# +------------+---------------------------+----------+----------+-----------+
# +-------------+----------+--------+------------+------+-----------+-------+
# | sqft_living | sqft_lot | floors | waterfront | view | condition | grade |
# ...

# %% [markdown]
# <img src = ".\house_images\house1.png">

# %%
print house1['price']
# Out:
# [620000.0, ... ]

# %%
print sqft_model.predict(house1)
print my_feature_model.predict(house1)
# Out:
# [629371.8046024732]
# [731101.0424500628]

# %% [markdown]
# ## Prediction for house2

# %%
house2 = sales[sales['id']=='1925069082']

# %%
house2
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: Unknown
#
# Data:
# +------------+---------------------------+-----------+----------+-----------+
# |     id     |            date           |   price   | bedrooms | bathrooms |
# +------------+---------------------------+-----------+----------+-----------+
# | 1925069082 | 2015-05-11 00:00:00+00:00 | 2200000.0 |   5.0    |    4.25   |
# +------------+---------------------------+-----------+----------+-----------+
# +-------------+----------+--------+------------+------+-----------+-------+
# | sqft_living | sqft_lot | floors | waterfront | view | condition | grade |
# ...

# %% [markdown]
# <img src = ".\house_images\house2.jpg">

# %%
print sqft_model.predict(house2)
print my_feature_model.predict(house2)
# Out:
# [1260271.2537525161]
# [1237062.765152122]

# %%
houses= sales[sales['zipcode']=='98039']

# %%
houses.show( )

# %%
house3 = sales[(sales['sqft_living']>2000) & (sales['sqft_living']<4000)]

# %%
house3.show()

# %%
from fractions import Fraction
print Fraction(9065,21509)
# Out:
# 9065/21509

# %%
advanced_features = [
'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode',
'condition', 
'grade',
'waterfront',
'view', 
'sqft_above', 
'sqft_basement',
'yr_built', 
'yr_renovated', 
'lat', 'long', 
'sqft_living15', # average sq.ft. of 15 nearest neighbors 
'sqft_lot15', 
]

# %%
my_advance_model= graphlab.linear_regression.create(train_data,target='price',features=advanced_features)
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 16544
# Number of features          : 18
# Number of unpacked features : 18
# Number of coefficients    : 87
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# | Iteration | Passes   | Elapsed Time | Training-max_error | Validation-max_error | Training-rmse | Validation-rmse |
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# | 1         | 2        | 0.067998     | 4323670.857931     | 1075673.896040       | 163134.134573 | 147338.003700   |
# ...

# %%
print my_feature_model.predict(test_data)
print my_advance_model.predict(test_data)
# Out:
# [272249.07757065503, 769388.5262200162, 273829.28641335317, 577867.0158755205, 396159.23150758154, 556995.441951737, 1030098.7175392195, 349836.14744627906, 200419.7423986144, 717031.9285472436, 289947.65062839503, 258243.3814579619, 247874.6148653146, 336681.7352943724, 464557.23901118035, 614948.9572343853, 821564.6397366169, 447282.79268526717, 792435.0623983876, 232770.1555007279, 940193.9003207217, 112188.50192917549, 404060.25538454275, 512043.9498284414, 786250.617095788, 333051.6188674418, 1201110.9927388087, 445670.2593279433, 233484.12448946576, 318227.2528021013, 101291.02066816778, 1031284.4266072577, 694002.412205975, 121447.63155198659, 319595.7784301813, 428957.6354481216, 189819.30611592365, 1140745.0030735151, 959111.2381734259, 297371.8397139639, 565575.4776383693, 243366.2308160479, 238049.49999805703, 465002.35837114125, 130264.31956313059, 1105626.9485945194, 869019.7034677465, 590627.1451511874, 315909.1093300113, 530993.7036684607, 348662.32564093254, 516861.39
# ...
